# %%
data = [11,5,7,13,2]
count=1
print(data)
for i in range(4):
    if data[i] > data[i+1]:
        temp=data[i]
        data[i]=data[i+1]
        data[i+1]=temp
    print(count,'=>',data)
    count+=1
    
count=1
print(data)
for i in range(3):
    if data[i] > data[i+1]:
        temp=data[i]
        data[i]=data[i+1]
        data[i+1]=temp
    print(count,'=>',data)
    count+=1
    
count=1
print(data)
for i in range(2):
    if data[i] > data[i+1]:
        temp=data[i]
        data[i]=data[i+1]
        data[i+1]=temp
    print(count,'=>',data)
    count+=1
    
count=1
print(data)
for i in range(1):
    if data[i] > data[i+1]:
        temp=data[i]
        data[i]=data[i+1]
        data[i+1]=temp
    print(count,'=>',data)
    count+=1
# Out:
# [11, 5, 7, 13, 2]
# 1 => [5, 11, 7, 13, 2]
# 2 => [5, 7, 11, 13, 2]
# 3 => [5, 7, 11, 13, 2]
# 4 => [5, 7, 11, 2, 13]
# [5, 7, 11, 2, 13]
# 1 => [5, 7, 11, 2, 13]
# 2 => [5, 7, 11, 2, 13]
# 3 => [5, 7, 2, 11, 13]
# [5, 7, 2, 11, 13]
# 1 => [5, 7, 2, 11, 13]
# 2 => [5, 2, 7, 11, 13]
# [5, 2, 7, 11, 13]
# 1 => [2, 5, 7, 11, 13]

# %% [markdown]
# modif decending , kiri ke kanan, kanan ke kiri, jika sudah terurut berhenti

# %%
# bubble short assending kiri ke kanan
data = [11,5,7,4,5,3,42,1,13,2,-1]
for j in range(len(data)-1,0,-1):
    print('#',j)
    count=0
    print(data)
    for i in range(j):
        if data[i] > data[i+1]:
            temp=data[i]
            data[i]=data[i+1]
            data[i+1]=temp
        print(count+i,'=>',data)
# Out:
# # 10
# [11, 5, 7, 4, 5, 3, 42, 1, 13, 2, -1]
# 0 => [5, 11, 7, 4, 5, 3, 42, 1, 13, 2, -1]
# 1 => [5, 7, 11, 4, 5, 3, 42, 1, 13, 2, -1]
# 2 => [5, 7, 4, 11, 5, 3, 42, 1, 13, 2, -1]
# 3 => [5, 7, 4, 5, 11, 3, 42, 1, 13, 2, -1]
# 4 => [5, 7, 4, 5, 3, 11, 42, 1, 13, 2, -1]
# 5 => [5, 7, 4, 5, 3, 11, 42, 1, 13, 2, -1]
# 6 => [5, 7, 4, 5, 3, 11, 1, 42, 13, 2, -1]
# 7 => [5, 7, 4, 5, 3, 11, 1, 13, 42, 2, -1]
# 8 => [5, 7, 4, 5, 3, 11, 1, 13, 2, 42, -1]
# 9 => [5, 7, 4, 5, 3, 11, 1, 13, 2, -1, 42]
# # 9
# [5, 7, 4, 5, 3, 11, 1, 13, 2, -1, 42]
# 0 => [5, 7, 4, 5, 3, 11, 1, 13, 2, -1, 42]
# 1 => [5, 4, 7, 5, 3, 11, 1, 13, 2, -1, 42]
# 2 => [5, 4, 5, 7, 3, 11, 1, 13, 2, -1, 42]
# 3 => [5, 4, 5, 3, 7, 11, 1, 13, 2, -1, 42]
# 4 => [5, 4, 5, 3, 7, 11, 1, 13, 2, -1, 42]
# 5 => [5, 4, 5, 3, 7, 1, 11, 13, 2, -1, 42]
# 6 => [5, 4, 5, 3, 7, 1, 11, 13, 2, -1, 42]
# 7 => [5, 4, 5, 3, 7, 1, 11, 2, 13, -1, 42]
# 8 => [5, 4, 5, 3, 7, 1, 11, 2, -1, 13, 42]
# # 8
# [5, 4, 5, 3, 7, 1, 11, 2, -1, 13, 42]
# 0 => [4, 5, 5, 3, 7, 1, 11, 2, -1, 13, 42]
# 1 => [4, 5, 5, 3, 7, 1, 11, 2, -1, 13, 42]
# 2 => [4, 5, 3, 5, 7, 1, 11, 2, -1, 13, 42]
# 3 => [4, 5, 3, 5, 7, 1, 11, 2, -1, 13, 42]
# 4 => [4, 5, 3, 5, 1, 7, 11, 2, -1, 13, 42]
# 5 => [4, 5, 3, 5, 1, 7, 11, 2, -1, 13, 42]
# 6 => [4, 5, 3, 5, 1, 7, 2, 11, -1, 13, 42]
# 7 => [4, 5, 3, 5, 1, 7, 2, -1, 11, 13, 42]
# # 7
# [4, 5, 3, 5, 1, 7, 2, -1, 11, 13, 42]
# 0 => [4, 5, 3, 5, 1, 7, 2, -1, 11, 13, 42]
# 1 => [4, 3, 5, 5, 1, 7, 2, -1, 11, 13, 42]
# 2 => [4, 3, 5, 5, 1, 7, 2, -1, 11, 13, 42]
# 3 => [4, 3, 5, 1, 5, 7, 2, -1, 11, 13, 42]
# 4 => [4, 3, 5, 1, 5, 7, 2, -1, 11, 13, 42]
# 5 => [4, 3, 5, 1, 5, 2, 7, -1, 11, 13, 42]
# 6 => [4, 3, 5, 1, 5, 2, -1, 7, 11, 13, 42]
# # 6
# [4, 3, 5, 1, 5, 2, -1, 7, 11, 13, 42]
# 0 => [3, 4, 5, 1, 5, 2, -1, 7, 11, 13, 42]
# 1 => [3, 4, 5, 1, 5, 2, -1, 7, 11, 13, 42]
# 2 => [3, 4, 1, 5, 5, 2, -1, 7, 11, 13, 42]
# 3 => [3, 4, 1, 5, 5, 2, -1, 7, 11, 13, 42]
# 4 => [3, 4, 1, 5, 2, 5, -1, 7, 11, 13, 42]
# 5 => [3, 4, 1, 5, 2, -1, 5, 7, 11, 13, 42]
# # 5
# [3, 4, 1, 5, 2, -1, 5, 7, 11, 13, 42]
# 0 => [3, 4, 1, 5, 2, -1, 5, 7, 11, 13, 42]
# 1 => [3, 1, 4, 5, 2, -1, 5, 7, 11, 13, 42]
# 2 => [3, 1, 4, 5, 2, -1, 5, 7, 11, 13, 42]
# 3 => [3, 1, 4, 2, 5, -1, 5, 7, 11, 13, 42]
# 4 => [3, 1, 4, 2, -1, 5, 5, 7, 11, 13, 42]
# # 4
# [3, 1, 4, 2, -1, 5, 5, 7, 11, 13, 42]
# 0 => [1, 3, 4, 2, -1, 5, 5, 7, 11, 13, 42]
# 1 => [1, 3, 4, 2, -1, 5, 5, 7, 11, 13, 42]
# 2 => [1, 3, 2, 4, -1, 5, 5, 7, 11, 13, 42]
# 3 => [1, 3, 2, -1, 4, 5, 5, 7, 11, 13, 42]
# # 3
# [1, 3, 2, -1, 4, 5, 5, 7, 11, 13, 42]
# 0 => [1, 3, 2, -1, 4, 5, 5, 7, 11, 13, 42]
# 1 => [1, 2, 3, -1, 4, 5, 5, 7, 11, 13, 42]
# 2 => [1, 2, -1, 3, 4, 5, 5, 7, 11, 13, 42]
# # 2
# [1, 2, -1, 3, 4, 5, 5, 7, 11, 13, 42]
# 0 => [1, 2, -1, 3, 4, 5, 5, 7, 11, 13, 42]
# 1 => [1, -1, 2, 3, 4, 5, 5, 7, 11, 13, 42]
# # 1
# [1, -1, 2, 3, 4, 5, 5, 7, 11, 13, 42]
# 0 => [-1, 1, 2, 3, 4, 5, 5, 7, 11, 13, 42]

# %%
# assending dari kanan ke kiri
def bubbleShort(listAgk):
    print('Data yang akan di urutkan',listAgk)
    for i in range(len(listAgk)-1,0,-1) :
        print('Iterasi ke-',len(listAgk)-i,'jumlah Iterasi = ',i)
        for j in range(len(listAgk)-1,len(listAgk)-i-1,-1):
#             print(i,j)
            if listAgk[j] < listAgk[j-1]:
                listAgk[j],listAgk[j-1] = listAgk[j-1],listAgk[j]
            print(j,'=>',listAgk)
    print('Data Terurut',listAgk)
    
bubbleShort([1,10,2,3,75,-7,4,5,-4])
# Out:
# Data yang akan di urutkan [1, 10, 2, 3, 75, -7, 4, 5, -4]
# Iterasi ke- 1 jumlah Iterasi =  8
# 8 => [1, 10, 2, 3, 75, -7, 4, -4, 5]
# 7 => [1, 10, 2, 3, 75, -7, -4, 4, 5]
# 6 => [1, 10, 2, 3, 75, -7, -4, 4, 5]
# 5 => [1, 10, 2, 3, -7, 75, -4, 4, 5]
# 4 => [1, 10, 2, -7, 3, 75, -4, 4, 5]
# 3 => [1, 10, -7, 2, 3, 75, -4, 4, 5]
# 2 => [1, -7, 10, 2, 3, 75, -4, 4, 5]
# 1 => [-7, 1, 10, 2, 3, 75, -4, 4, 5]
# Iterasi ke- 2 jumlah Iterasi =  7
# 8 => [-7, 1, 10, 2, 3, 75, -4, 4, 5]
# 7 => [-7, 1, 10, 2, 3, 75, -4, 4, 5]
# 6 => [-7, 1, 10, 2, 3, -4, 75, 4, 5]
# 5 => [-7, 1, 10, 2, -4, 3, 75, 4, 5]
# 4 => [-7, 1, 10, -4, 2, 3, 75, 4, 5]
# 3 => [-7, 1, -4, 10, 2, 3, 75, 4, 5]
# 2 => [-7, -4, 1, 10, 2, 3, 75, 4, 5]
# Iterasi ke- 3 jumlah Iterasi =  6
# 8 => [-7, -4, 1, 10, 2, 3, 75, 4, 5]
# 7 => [-7, -4, 1, 10, 2, 3, 4, 75, 5]
# 6 => [-7, -4, 1, 10, 2, 3, 4, 75, 5]
# 5 => [-7, -4, 1, 10, 2, 3, 4, 75, 5]
# 4 => [-7, -4, 1, 2, 10, 3, 4, 75, 5]
# 3 => [-7, -4, 1, 2, 10, 3, 4, 75, 5]
# Iterasi ke- 4 jumlah Iterasi =  5
# 8 => [-7, -4, 1, 2, 10, 3, 4, 5, 75]
# 7 => [-7, -4, 1, 2, 10, 3, 4, 5, 75]
# 6 => [-7, -4, 1, 2, 10, 3, 4, 5, 75]
# 5 => [-7, -4, 1, 2, 3, 10, 4, 5, 75]
# 4 => [-7, -4, 1, 2, 3, 10, 4, 5, 75]
# Iterasi ke- 5 jumlah Iterasi =  4
# 8 => [-7, -4, 1, 2, 3, 10, 4, 5, 75]
# 7 => [-7, -4, 1, 2, 3, 10, 4, 5, 75]
# 6 => [-7, -4, 1, 2, 3, 4, 10, 5, 75]
# 5 => [-7, -4, 1, 2, 3, 4, 10, 5, 75]
# Iterasi ke- 6 jumlah Iterasi =  3
# 8 => [-7, -4, 1, 2, 3, 4, 10, 5, 75]
# 7 => [-7, -4, 1, 2, 3, 4, 5, 10, 75]
# 6 => [-7, -4, 1, 2, 3, 4, 5, 10, 75]
# Iterasi ke- 7 jumlah Iterasi =  2
# 8 => [-7, -4, 1, 2, 3, 4, 5, 10, 75]
# 7 => [-7, -4, 1, 2, 3, 4, 5, 10, 75]
# Iterasi ke- 8 jumlah Iterasi =  1
# 8 => [-7, -4, 1, 2, 3, 4, 5, 10, 75]
# Data Terurut [-7, -4, 1, 2, 3, 4, 5, 10, 75]

# %%
# bubble short decending kiri ke kanan
data = [-1,11,5,7,4,5,3,42,1,13,2,-1]
for j in range(len(data)-1,0,-1):
    print('#',j)
    count=0
    print(data)
    for i in range(j):
        if data[i] < data[i+1]:
            temp=data[i]
            data[i]=data[i+1]
            data[i+1]=temp
        print(count+i,'=>',data)
# Out:
# # 11
# [-1, 11, 5, 7, 4, 5, 3, 42, 1, 13, 2, -1]
# 0 => [11, -1, 5, 7, 4, 5, 3, 42, 1, 13, 2, -1]
# 1 => [11, 5, -1, 7, 4, 5, 3, 42, 1, 13, 2, -1]
# 2 => [11, 5, 7, -1, 4, 5, 3, 42, 1, 13, 2, -1]
# 3 => [11, 5, 7, 4, -1, 5, 3, 42, 1, 13, 2, -1]
# 4 => [11, 5, 7, 4, 5, -1, 3, 42, 1, 13, 2, -1]
# 5 => [11, 5, 7, 4, 5, 3, -1, 42, 1, 13, 2, -1]
# 6 => [11, 5, 7, 4, 5, 3, 42, -1, 1, 13, 2, -1]
# 7 => [11, 5, 7, 4, 5, 3, 42, 1, -1, 13, 2, -1]
# 8 => [11, 5, 7, 4, 5, 3, 42, 1, 13, -1, 2, -1]
# 9 => [11, 5, 7, 4, 5, 3, 42, 1, 13, 2, -1, -1]
# 10 => [11, 5, 7, 4, 5, 3, 42, 1, 13, 2, -1, -1]
# # 10
# [11, 5, 7, 4, 5, 3, 42, 1, 13, 2, -1, -1]
# 0 => [11, 5, 7, 4, 5, 3, 42, 1, 13, 2, -1, -1]
# 1 => [11, 7, 5, 4, 5, 3, 42, 1, 13, 2, -1, -1]
# 2 => [11, 7, 5, 4, 5, 3, 42, 1, 13, 2, -1, -1]
# 3 => [11, 7, 5, 5, 4, 3, 42, 1, 13, 2, -1, -1]
# 4 => [11, 7, 5, 5, 4, 3, 42, 1, 13, 2, -1, -1]
# 5 => [11, 7, 5, 5, 4, 42, 3, 1, 13, 2, -1, -1]
# 6 => [11, 7, 5, 5, 4, 42, 3, 1, 13, 2, -1, -1]
# 7 => [11, 7, 5, 5, 4, 42, 3, 13, 1, 2, -1, -1]
# 8 => [11, 7, 5, 5, 4, 42, 3, 13, 2, 1, -1, -1]
# 9 => [11, 7, 5, 5, 4, 42, 3, 13, 2, 1, -1, -1]
# # 9
# [11, 7, 5, 5, 4, 42, 3, 13, 2, 1, -1, -1]
# 0 => [11, 7, 5, 5, 4, 42, 3, 13, 2, 1, -1, -1]
# 1 => [11, 7, 5, 5, 4, 42, 3, 13, 2, 1, -1, -1]
# 2 => [11, 7, 5, 5, 4, 42, 3, 13, 2, 1, -1, -1]
# 3 => [11, 7, 5, 5, 4, 42, 3, 13, 2, 1, -1, -1]
# 4 => [11, 7, 5, 5, 42, 4, 3, 13, 2, 1, -1, -1]
# 5 => [11, 7, 5, 5, 42, 4, 3, 13, 2, 1, -1, -1]
# 6 => [11, 7, 5, 5, 42, 4, 13, 3, 2, 1, -1, -1]
# 7 => [11, 7, 5, 5, 42, 4, 13, 3, 2, 1, -1, -1]
# 8 => [11, 7, 5, 5, 42, 4, 13, 3, 2, 1, -1, -1]
# # 8
# [11, 7, 5, 5, 42, 4, 13, 3, 2, 1, -1, -1]
# 0 => [11, 7, 5, 5, 42, 4, 13, 3, 2, 1, -1, -1]
# 1 => [11, 7, 5, 5, 42, 4, 13, 3, 2, 1, -1, -1]
# 2 => [11, 7, 5, 5, 42, 4, 13, 3, 2, 1, -1, -1]
# 3 => [11, 7, 5, 42, 5, 4, 13, 3, 2, 1, -1, -1]
# 4 => [11, 7, 5, 42, 5, 4, 13, 3, 2, 1, -1, -1]
# 5 => [11, 7, 5, 42, 5, 13, 4, 3, 2, 1, -1, -1]
# 6 => [11, 7, 5, 42, 5, 13, 4, 3, 2, 1, -1, -1]
# 7 => [11, 7, 5, 42, 5, 13, 4, 3, 2, 1, -1, -1]
# # 7
# [11, 7, 5, 42, 5, 13, 4, 3, 2, 1, -1, -1]
# 0 => [11, 7, 5, 42, 5, 13, 4, 3, 2, 1, -1, -1]
# 1 => [11, 7, 5, 42, 5, 13, 4, 3, 2, 1, -1, -1]
# 2 => [11, 7, 42, 5, 5, 13, 4, 3, 2, 1, -1, -1]
# 3 => [11, 7, 42, 5, 5, 13, 4, 3, 2, 1, -1, -1]
# 4 => [11, 7, 42, 5, 13, 5, 4, 3, 2, 1, -1, -1]
# 5 => [11, 7, 42, 5, 13, 5, 4, 3, 2, 1, -1, -1]
# 6 => [11, 7, 42, 5, 13, 5, 4, 3, 2, 1, -1, -1]
# # 6
# [11, 7, 42, 5, 13, 5, 4, 3, 2, 1, -1, -1]
# 0 => [11, 7, 42, 5, 13, 5, 4, 3, 2, 1, -1, -1]
# 1 => [11, 42, 7, 5, 13, 5, 4, 3, 2, 1, -1, -1]
# 2 => [11, 42, 7, 5, 13, 5, 4, 3, 2, 1, -1, -1]
# 3 => [11, 42, 7, 13, 5, 5, 4, 3, 2, 1, -1, -1]
# 4 => [11, 42, 7, 13, 5, 5, 4, 3, 2, 1, -1, -1]
# 5 => [11, 42, 7, 13, 5, 5, 4, 3, 2, 1, -1, -1]
# # 5
# [11, 42, 7, 13, 5, 5, 4, 3, 2, 1, -1, -1]
# 0 => [42, 11, 7, 13, 5, 5, 4, 3, 2, 1, -1, -1]
# 1 => [42, 11, 7, 13, 5, 5, 4, 3, 2, 1, -1, -1]
# 2 => [42, 11, 13, 7, 5, 5, 4, 3, 2, 1, -1, -1]
# 3 => [42, 11, 13, 7, 5, 5, 4, 3, 2, 1, -1, -1]
# 4 => [42, 11, 13, 7, 5, 5, 4, 3, 2, 1, -1, -1]
# # 4
# [42, 11, 13, 7, 5, 5, 4, 3, 2, 1, -1, -1]
# 0 => [42, 11, 13, 7, 5, 5, 4, 3, 2, 1, -1, -1]
# 1 => [42, 13, 11, 7, 5, 5, 4, 3, 2, 1, -1, -1]
# 2 => [42, 13, 11, 7, 5, 5, 4, 3, 2, 1, -1, -1]
# 3 => [42, 13, 11, 7, 5, 5, 4, 3, 2, 1, -1, -1]
# # 3
# [42, 13, 11, 7, 5, 5, 4, 3, 2, 1, -1, -1]
# 0 => [42, 13, 11, 7, 5, 5, 4, 3, 2, 1, -1, -1]
# 1 => [42, 13, 11, 7, 5, 5, 4, 3, 2, 1, -1, -1]
# 2 => [42, 13, 11, 7, 5, 5, 4, 3, 2, 1, -1, -1]
# # 2
# [42, 13, 11, 7, 5, 5, 4, 3, 2, 1, -1, -1]
# 0 => [42, 13, 11, 7, 5, 5, 4, 3, 2, 1, -1, -1]
# 1 => [42, 13, 11, 7, 5, 5, 4, 3, 2, 1, -1, -1]
# # 1
# [42, 13, 11, 7, 5, 5, 4, 3, 2, 1, -1, -1]
# 0 => [42, 13, 11, 7, 5, 5, 4, 3, 2, 1, -1, -1]

# %%
#bubblesort decending dari kanan ke kiri
def bubbleShort(listData):
    print('Data yang akan di urutkan',listData)
    count=0
    for outIter in range(len(listData)-1,-1,-1):
        print('outIter',outIter)
        count+=1
        print('iterasi ke',count)
        for i in range(len(listData)-1,len(listData)-outIter-1,-1):
            if listData[i] > listData[i-1]:
                temp =  listData[i]
                listData[i]=listData[i-1]
                listData[i-1]=temp
#                 listData[i],listData[i+1]=listData[i+1],listData[i]
            print(i,'=',listData)
    print('Data urut-',listData)
bubbleShort([-2,100,11,51,7,13,2,-1,70])
# Out:
# Data yang akan di urutkan [-2, 100, 11, 51, 7, 13, 2, -1, 70]
# outIter 8
# iterasi ke 1
# 8 = [-2, 100, 11, 51, 7, 13, 2, 70, -1]
# 7 = [-2, 100, 11, 51, 7, 13, 70, 2, -1]
# 6 = [-2, 100, 11, 51, 7, 70, 13, 2, -1]
# 5 = [-2, 100, 11, 51, 70, 7, 13, 2, -1]
# 4 = [-2, 100, 11, 70, 51, 7, 13, 2, -1]
# 3 = [-2, 100, 70, 11, 51, 7, 13, 2, -1]
# 2 = [-2, 100, 70, 11, 51, 7, 13, 2, -1]
# 1 = [100, -2, 70, 11, 51, 7, 13, 2, -1]
# outIter 7
# iterasi ke 2
# 8 = [100, -2, 70, 11, 51, 7, 13, 2, -1]
# 7 = [100, -2, 70, 11, 51, 7, 13, 2, -1]
# 6 = [100, -2, 70, 11, 51, 13, 7, 2, -1]
# 5 = [100, -2, 70, 11, 51, 13, 7, 2, -1]
# 4 = [100, -2, 70, 51, 11, 13, 7, 2, -1]
# 3 = [100, -2, 70, 51, 11, 13, 7, 2, -1]
# 2 = [100, 70, -2, 51, 11, 13, 7, 2, -1]
# outIter 6
# iterasi ke 3
# 8 = [100, 70, -2, 51, 11, 13, 7, 2, -1]
# 7 = [100, 70, -2, 51, 11, 13, 7, 2, -1]
# 6 = [100, 70, -2, 51, 11, 13, 7, 2, -1]
# 5 = [100, 70, -2, 51, 13, 11, 7, 2, -1]
# 4 = [100, 70, -2, 51, 13, 11, 7, 2, -1]
# 3 = [100, 70, 51, -2, 13, 11, 7, 2, -1]
# outIter 5
# iterasi ke 4
# 8 = [100, 70, 51, -2, 13, 11, 7, 2, -1]
# 7 = [100, 70, 51, -2, 13, 11, 7, 2, -1]
# 6 = [100, 70, 51, -2, 13, 11, 7, 2, -1]
# 5 = [100, 70, 51, -2, 13, 11, 7, 2, -1]
# 4 = [100, 70, 51, 13, -2, 11, 7, 2, -1]
# outIter 4
# iterasi ke 5
# 8 = [100, 70, 51, 13, -2, 11, 7, 2, -1]
# 7 = [100, 70, 51, 13, -2, 11, 7, 2, -1]
# 6 = [100, 70, 51, 13, -2, 11, 7, 2, -1]
# 5 = [100, 70, 51, 13, 11, -2, 7, 2, -1]
# outIter 3
# iterasi ke 6
# 8 = [100, 70, 51, 13, 11, -2, 7, 2, -1]
# 7 = [100, 70, 51, 13, 11, -2, 7, 2, -1]
# 6 = [100, 70, 51, 13, 11, 7, -2, 2, -1]
# outIter 2
# iterasi ke 7
# 8 = [100, 70, 51, 13, 11, 7, -2, 2, -1]
# 7 = [100, 70, 51, 13, 11, 7, 2, -2, -1]
# outIter 1
# iterasi ke 8
# 8 = [100, 70, 51, 13, 11, 7, 2, -1, -2]
# outIter 0
# iterasi ke 9
# Data urut- [100, 70, 51, 13, 11, 7, 2, -1, -2]

# %%
def modifBubbleShort(listAgk):
    print('Data yang akan di urutkan',listAgk)
    i = len(listAgk)-1
    while i > 0:
        print('Iterasi ke-',len(listAgk)-i,'Jumlah Iterasi = ',i)
        temp=0
        for j in range(i):
            if listAgk[j] > listAgk[j+1]:
                listAgk[j+1],listAgk[j] = listAgk[j],listAgk[j+1]
                temp+=1
            print(j,'=>',listAgk)
        i-=1
        if temp == 0 :
            i=0
    print('Data Terurut',listAgk)
    
modifBubbleShort([1,10,2,2,2,3,4,5,2])
# Out:
# Data yang akan di urutkan [1, 10, 2, 2, 2, 3, 4, 5, 2]
# Iterasi ke- 1 Jumlah Iterasi =  8
# 0 => [1, 10, 2, 2, 2, 3, 4, 5, 2]
# 1 => [1, 2, 10, 2, 2, 3, 4, 5, 2]
# 2 => [1, 2, 2, 10, 2, 3, 4, 5, 2]
# 3 => [1, 2, 2, 2, 10, 3, 4, 5, 2]
# 4 => [1, 2, 2, 2, 3, 10, 4, 5, 2]
# 5 => [1, 2, 2, 2, 3, 4, 10, 5, 2]
# 6 => [1, 2, 2, 2, 3, 4, 5, 10, 2]
# 7 => [1, 2, 2, 2, 3, 4, 5, 2, 10]
# Iterasi ke- 2 Jumlah Iterasi =  7
# 0 => [1, 2, 2, 2, 3, 4, 5, 2, 10]
# 1 => [1, 2, 2, 2, 3, 4, 5, 2, 10]
# 2 => [1, 2, 2, 2, 3, 4, 5, 2, 10]
# 3 => [1, 2, 2, 2, 3, 4, 5, 2, 10]
# 4 => [1, 2, 2, 2, 3, 4, 5, 2, 10]
# 5 => [1, 2, 2, 2, 3, 4, 5, 2, 10]
# 6 => [1, 2, 2, 2, 3, 4, 2, 5, 10]
# Iterasi ke- 3 Jumlah Iterasi =  6
# 0 => [1, 2, 2, 2, 3, 4, 2, 5, 10]
# 1 => [1, 2, 2, 2, 3, 4, 2, 5, 10]
# 2 => [1, 2, 2, 2, 3, 4, 2, 5, 10]
# 3 => [1, 2, 2, 2, 3, 4, 2, 5, 10]
# 4 => [1, 2, 2, 2, 3, 4, 2, 5, 10]
# 5 => [1, 2, 2, 2, 3, 2, 4, 5, 10]
# Iterasi ke- 4 Jumlah Iterasi =  5
# 0 => [1, 2, 2, 2, 3, 2, 4, 5, 10]
# 1 => [1, 2, 2, 2, 3, 2, 4, 5, 10]
# 2 => [1, 2, 2, 2, 3, 2, 4, 5, 10]
# 3 => [1, 2, 2, 2, 3, 2, 4, 5, 10]
# 4 => [1, 2, 2, 2, 2, 3, 4, 5, 10]
# Iterasi ke- 5 Jumlah Iterasi =  4
# 0 => [1, 2, 2, 2, 2, 3, 4, 5, 10]
# 1 => [1, 2, 2, 2, 2, 3, 4, 5, 10]
# 2 => [1, 2, 2, 2, 2, 3, 4, 5, 10]
# 3 => [1, 2, 2, 2, 2, 3, 4, 5, 10]
# Data Terurut [1, 2, 2, 2, 2, 3, 4, 5, 10]

# %%
def bidirectional(lst):
    kiri = 0
    kanan= len(lst)-1
    count=1
    while kiri < kanan:
        print('#',count)
        for i in range(kiri,kanan):
            if lst[i]>lst[i+1]:
                lst[i],lst[i+1]=lst[i+1],lst[i]
            print('kanan',lst)
        kanan-=1
        for j in range(kanan,kiri,-1):
            if lst[j] < lst[j-1]:
                lst[j],lst[j-1]=lst[j-1],lst[j]
            print('kiri',lst)
        kiri+=1
        count+=1
    return lst
print(bidirectional([100,3,7,3,6,4,90,0]))
# Out:
# # 1
# kanan [3, 100, 7, 3, 6, 4, 90, 0]
# kanan [3, 7, 100, 3, 6, 4, 90, 0]
# kanan [3, 7, 3, 100, 6, 4, 90, 0]
# kanan [3, 7, 3, 6, 100, 4, 90, 0]
# kanan [3, 7, 3, 6, 4, 100, 90, 0]
# kanan [3, 7, 3, 6, 4, 90, 100, 0]
# kanan [3, 7, 3, 6, 4, 90, 0, 100]
# kiri [3, 7, 3, 6, 4, 0, 90, 100]
# kiri [3, 7, 3, 6, 0, 4, 90, 100]
# kiri [3, 7, 3, 0, 6, 4, 90, 100]
# kiri [3, 7, 0, 3, 6, 4, 90, 100]
# kiri [3, 0, 7, 3, 6, 4, 90, 100]
# kiri [0, 3, 7, 3, 6, 4, 90, 100]
# # 2
# kanan [0, 3, 7, 3, 6, 4, 90, 100]
# kanan [0, 3, 3, 7, 6, 4, 90, 100]
# kanan [0, 3, 3, 6, 7, 4, 90, 100]
# kanan [0, 3, 3, 6, 4, 7, 90, 100]
# kanan [0, 3, 3, 6, 4, 7, 90, 100]
# kiri [0, 3, 3, 6, 4, 7, 90, 100]
# kiri [0, 3, 3, 4, 6, 7, 90, 100]
# kiri [0, 3, 3, 4, 6, 7, 90, 100]
# kiri [0, 3, 3, 4, 6, 7, 90, 100]
# # 3
# kanan [0, 3, 3, 4, 6, 7, 90, 100]
# kanan [0, 3, 3, 4, 6, 7, 90, 100]
# kanan [0, 3, 3, 4, 6, 7, 90, 100]
# kiri [0, 3, 3, 4, 6, 7, 90, 100]
# kiri [0, 3, 3, 4, 6, 7, 90, 100]
# # 4
# kanan [0, 3, 3, 4, 6, 7, 90, 100]
# [0, 3, 3, 4, 6, 7, 90, 100]
