# %%
def stack():
    s=[]
    return (s)
def push(s,data):
    s.append(data)
def pop(s):
    data=s.pop()
    return(data)
def peek(s):
    return(s[len(s)-1])
def isEmpty(s):
    return (s==[])
def size(s):
    return(len(s))

# %%
def validateTagHTML(html):
    st=stack()
    html=html.split()
    html=html[1:-1]
    error=[False,'Error :']
    for tag in html:
        if tag[0]=='<' and tag[1]!='/':
            push(st,tag)
        else:
            if tag[0]=='<' and tag[1]=='/':
                if not isEmpty(st):
                    if peek(st)[1:-1]==tag[2:-1]:
                        pop(st)
                    else:
                        error.append(str(len(error)-1)+'. Open tag '+tag+'--> '+peek(st))
                        pop(st)
                else:
                    error.append(str(len(error)-1)+'. kelebihan Close tag : '+tag)
        print(st)
    if len(error)==2 and size(st)==0:
        return True
    else:
        for i in range(size(st)):
            error.append(str(len(error)-1)+'. Kelebihan Open tag : '+pop(st))
        return error

inp="""
<html>
<body>
<title>
Praktikum Struktur Data/
</title>
<h1>
Stack
</h1>
</body>
</html>
"""

validateTagHTML(inp)
# Out:
# ['<body>']
# ['<body>', '<title>']
# ['<body>', '<title>']
# ['<body>', '<title>']
# ['<body>', '<title>']
# ['<body>']
# ['<body>', '<h1>']
# ['<body>', '<h1>']
# ['<body>']
# []
# True

# %%
#bubble sorting pertemuan 20 maret
data=[7,2,1,5,4,12,0]
for it in range(len(data)-1):
    print('iterasi ke- ',it)
    print('data awal : ',data)
    maksData=data[0]
    for i in range(1,len(data)-it):
        print(maksData,'<',data[i])
        if maksData<data[i]:
            maksData=data[i]
            idmaks=i
    print('malksimal = ',maksData,'indeks = ',idmaks)
    data[idmaks]=data[len(data)-(it+1)]
    data[len(data)-(it+1)]==maksData
    
    print('data sort temp =',data)
    print(' ')
# Out:
# iterasi ke-  0
# data awal :  [7, 2, 1, 5, 4, 12, 0]
# 7 < 2
# 7 < 1
# 7 < 5
# 7 < 4
# 7 < 12
# 12 < 0
# malksimal =  12 indeks =  5
# data sort temp = [7, 2, 1, 5, 4, 0, 0]
#
# iterasi ke-  1
# data awal :  [7, 2, 1, 5, 4, 0, 0]
# 7 < 2
# 7 < 1
# 7 < 5
# 7 < 4
# 7 < 0
# malksimal =  7 indeks =  5
# data sort temp = [7, 2, 1, 5, 4, 0, 0]
#
# iterasi ke-  2
# data awal :  [7, 2, 1, 5, 4, 0, 0]
# 7 < 2
# 7 < 1
# 7 < 5
# 7 < 4
# malksimal =  7 indeks =  5
# data sort temp = [7, 2, 1, 5, 4, 4, 0]
#
# iterasi ke-  3
# data awal :  [7, 2, 1, 5, 4, 4, 0]
# 7 < 2
# 7 < 1
# 7 < 5
# malksimal =  7 indeks =  5
# data sort temp = [7, 2, 1, 5, 4, 5, 0]
#
# iterasi ke-  4
# data awal :  [7, 2, 1, 5, 4, 5, 0]
# 7 < 2
# 7 < 1
# malksimal =  7 indeks =  5
# data sort temp = [7, 2, 1, 5, 4, 1, 0]
#
# iterasi ke-  5
# data awal :  [7, 2, 1, 5, 4, 1, 0]
# 7 < 2
# malksimal =  7 indeks =  5
# data sort temp = [7, 2, 1, 5, 4, 2, 0]

# %%
#latihan uts kode -1
def fpdouble(akg1,akg2) :
    lst1 = []
    lst2 = []
    hs   = []
    
    for i in range(1,akg1+1) :
        if akg1 % i == 0 :
            lst1.append(i)

    
    for i in range(1,akg2+1) :
        if akg2 % i == 0 :
            lst2.append(i)
        
    for ls1 in lst1 :
        for ls2 in lst2 :
            if ls1 == ls2 :
                hs.append(ls1)
                
    return hs


fp = fpdouble(36,48)
print(fp)
# Out:
# [1, 2, 3, 4, 6, 12]

# %%
def fpdouble(akg1,akg2) :
    hs   = []
    if akg1 > akg2 :
        akg = akg1
    else :
        akg = akg2
    
    for i in range(1,akg+1) :
        if akg1 % i == 0 and akg2 % i == 0 :
            hs.append(i)
            
    return hs


fp = fpdouble(36,48)
print(fp)
# Out:
# [1, 2, 3, 4, 6, 12]

# %%
angka1=30
angka2=25
while angka1 !=30:
    for i in range(1,angka1+1):
        if angka1%i==0:
            print(i)
print('====')
angka2=25
for j in range(1,angka2+1):
    if angka2%j==0:
        print(j)
# Out:
# ====
# 1
# 5
# 25

# %%
def kalkulasi(angka1,angka2):
    stek=stack()
    for i in range(angka1):
        if angka%i==0:
            print(i)

# %%
# sesi 2 uts
def bubbleSort(nums) :
    print("\n\nData Awal = ",nums)
    no = 1
    for i in range (len(nums)-1,0,-1): 

        no2 = 1
        print("\nIterasi utama ke-",no," = ",nums)
        for j in range(len(nums)-1,len(nums)-i-1,-1) : 
            
            if nums[j] > nums[j-1] :
                nums[j],nums[j-1] = nums[j-1],nums[j]
            print("#%d : data[%d,%d] = %d dan %d -> %s " % (no2,j,j-1,nums[j-1],nums[j],nums) )
            
            no2+=1
        no+=1
        
    return nums

lstNums = [1,12,50,75,83,126,56,87,90]
print("\n\nData Terurut = ",bubbleSort(lstNums))
# Out:
# Data Awal =  [1, 12, 50, 75, 83, 126, 56, 87, 90]
#
# Iterasi utama ke- 1  =  [1, 12, 50, 75, 83, 126, 56, 87, 90]
# #1 : data[8,7] = 90 dan 87 -> [1, 12, 50, 75, 83, 126, 56, 90, 87]
# #2 : data[7,6] = 90 dan 56 -> [1, 12, 50, 75, 83, 126, 90, 56, 87]
# #3 : data[6,5] = 126 dan 90 -> [1, 12, 50, 75, 83, 126, 90, 56, 87]
# #4 : data[5,4] = 126 dan 83 -> [1, 12, 50, 75, 126, 83, 90, 56, 87]
# #5 : data[4,3] = 126 dan 75 -> [1, 12, 50, 126, 75, 83, 90, 56, 87]
# #6 : data[3,2] = 126 dan 50 -> [1, 12, 126, 50, 75, 83, 90, 56, 87]
# #7 : data[2,1] = 126 dan 12 -> [1, 126, 12, 50, 75, 83, 90, 56, 87]
# #8 : data[1,0] = 126 dan 1 -> [126, 1, 12, 50, 75, 83, 90, 56, 87]
#
# Iterasi utama ke- 2  =  [126, 1, 12, 50, 75, 83, 90, 56, 87]
# #1 : data[8,7] = 87 dan 56 -> [126, 1, 12, 50, 75, 83, 90, 87, 56]
# #2 : data[7,6] = 90 dan 87 -> [126, 1, 12, 50, 75, 83, 90, 87, 56]
# #3 : data[6,5] = 90 dan 83 -> [126, 1, 12, 50, 75, 90, 83, 87, 56]
# ...

# %%
#uts kode 3
# from stack import *

def jmlStack(bil1,bil2) :
    bilStack = stack()
    bl1 = stack()
    bl2 = stack()
    tmp = 0
    bilStr = ""
    
    for b1 in bil1 :
        push(bl1,b1)
    
    for b2 in bil2 :
        push(bl2,b2)
   
      
    while not(isEmpty(bl1)) or not(isEmpty(bl2)) :
        hs = 0
        
        print("""
Stack bil 1 = %s
Stack bil 2 = %s """ % (bl1,bl2))
       
        if not(isEmpty(bl1)) and isEmpty(bl2) :
           
            hs = int(pop(bl1))+tmp
            hsStr = str(hs)
            if len(hsStr) > 1 and not(isEmpty(bl1)):
                tmp = int(hsStr[0])
                push(bilStack,int(hsStr[1]))
            else :
                push(bilStack,hs)
                tmp=0
            
            
        elif not(isEmpty(bl2)) and isEmpty(bl1) :
            
            hs = int(pop(bl2))+tmp
            print(hs)
            hsStr = str(hs)
            if len(hsStr) > 1 and not(isEmpty(bl2)) :
                tmp = int(hsStr[0])
                push(bilStack,int(hsStr[1]))
            else :
                push(bilStack,hs)
                tmp=0
            
            
        elif not(isEmpty(bl1)) and not(isEmpty(bl2)) :
            hs    = int(pop(bl1))+int(pop(bl2))+tmp
            hsStr = str(hs)
            
            if len(hsStr) > 1 :
                tmp = int(hsStr[0])
                push(bilStack,int(hsStr[1]))
            else :
                push(bilStack,hs)
        
        print(bilStack)
            
    
    while not(isEmpty(bilStack)) :
        bil = str(pop(bilStack))
        bilStr+=bil
    return bilStr


akg1 = "777"
akg2 = "3"
print("\n\n Jml Bilangan %s + %s = %s "% (akg1,akg2,jmlStack(akg1,akg2)) )
# Out:
# Stack bil 1 = ['7', '7', '7']
# Stack bil 2 = ['3']
# [0]
#
# Stack bil 1 = ['7', '7']
# Stack bil 2 = []
# [0, 8]
#
# Stack bil 1 = ['7']
# Stack bil 2 = []
# [0, 8, 7]
#
#
#  Jml Bilangan 777 + 3 = 780

# %% [markdown]
# # Teori

# %%
#stack
def createStack() :
    stck = []
    return stck

def push(s,data) :
    s.append(data)

def pop(s) :
    dt = s.pop()
    return dt

def peek(s) :
    return s[len(s)-1]

def isEmpty(s) :
    return s==[]

def size(s) :
    return len(s)

# %%
#queue
def createQueue() :
    return []

def enqueue(q,data):
    q.append(data)
    return(q)

def dequeue(q):
    data=q.pop(0)
    return(data)

def isEmpty(q):
    return (q==[])

def size(q):
    return (len(q))

# %%
#deque
def createDeque() :
    return []

def addFront(d,val) :
    d.insert(0,val)
    return d

def addRear(d,val) :
    d.append(val)
    return d

def removeFront(d) :
    val = d.pop(0)
    return val

def removeRear(d) :
    val = d.pop()
    return val

def isEmpty(d) :
    return d==[]

def size(d) :
    return len(d)

# %%
#buble sort
def bubbleSort(nums,sortBy="Ascending") :
    
    if sortBy == "Ascending" :
        for i in range (len(nums)-1): 
            for j in range(len(nums)-1-i) :
                if nums[j] > nums[j+1] :
                    nums[j],nums[j+1] = nums[j+1],nums[j]
                    
    elif sortBy == "Descending" :
        for i in range (len(nums)-1): 
            
            for j in range(len(nums)-1-i) : 
                if nums[j] < nums[j+1] :
                    nums[j],nums[j+1] = nums[j+1],nums[j]
                
                
    return nums

print(bubbleSort([9,10,1,7] ,"Ascending"))
# Out:
# [1, 7, 9, 10]

# %%
#parntese check

def bacaOperator(strOp,stackOp) :
    print("""
Baca " %s "
Stack :
 """ % (strOp))
    
    for sto in stackOp :
        print("| %s |" % (sto) )

    print("-----")
     
    
    
def checkParentheses(strOp) :
    stKurung    = createStack()
    kurungBuka  = ("(","[","{")
    kurungTutup = (")","]","}")
    temp        = ''
    tmp         = ''
    matched     = True
    ttl         = 0
    krt         = False
    
    for so in strOp :
       
        if so in kurungBuka :
            push(stKurung,so)
            #bacaOperator(so,stKurung)
            
        elif so in kurungTutup :
            #bacaOperator(so,stKurung)
            if not(isEmpty(stKurung)) :
                
                if kurungBuka.index(peek(stKurung)) == kurungTutup.index(so) :
                    stTmp=pop(stKurung)
                    matched = matched and True
                else :
                    stTmp   = pop(stKurung)
                    matched = matched and False
                    tmp     = so
                    temp    = stTmp
                    
            else :
                #print(ttl)
                krt = True
                ttl+=1
                
   
    print(stKurung)
    if isEmpty(stKurung) and matched and not(krt) :
        return "OK"
    elif isEmpty(stKurung) and not(matched) and not(krt) :
        return temp+" Tidak cocok dengan "+tmp
    elif not(isEmpty(stKurung)) :
        if matched :
            return "Kelebihan %d Kurung Buka" % (ttl)
        else :
            return "%s Tidak cocok dengan %s dan Kelebihan %d Kurung Buka" % (temp,tmp,ttl)
    elif isEmpty(stKurung) and krt :
        if matched :
            return "Kelebihan %d Kurung Tutup" % (ttl)
        else :
            return "%s Tidak cocok dengan %s dan Kelebihan %d Kurung Tutup" % (temp,tmp,ttl)
    
print("\n",checkParentheses("{((4+5)))"))
# Out:
# []
#
#  { Tidak cocok dengan )

# %%
#infix to prefix

def reverseWrd(wrd) :
    wrl = stack()
    wrn = ""
    for w in wrd :
        push(wrl,w)

    for i in range(len(wrl)) :
        wr = pop(wrl)
        if wr == ")" :
            wrn+="("
        elif wr == "(" :
            wrn+=")"
        else :
            wrn+=wr

    return wrn

def convertPrefix(strOp) :
    strOp      = reverseWrd(strOp)
    print(strOp)
    stOperator = stack()
    kurung     = ("(",")")
    operator   = {"+":0,"-":0,"*":1,"/":1}
    strRes     = ""
    
    for sto in strOp :
        if sto not in operator.keys() and sto not in kurung :
            strRes=sto+strRes
        
        elif sto == kurung[0] :
            push(stOperator,sto)
            
        elif sto == kurung[1] :
            while peek(stOperator) != kurung[0] :
                strRes=pop(stOperator)+strRes
            pop(stOperator)
            
            
        elif sto in operator.keys() :
            while not(isEmpty(stOperator)) and peek(stOperator) != kurung[0] and operator[peek(stOperator)] >= operator[sto] :   
                strRes=st.pop(stOperator)+strRes
            push(stOperator,sto)
        
            
    while not(isEmpty(stOperator)) :
        strRes=pop(stOperator)+strRes
            
            
    return strRes


print("Prefix : ",convertPrefix("2*7+1"))
print("Prefix : ",convertPrefix("2*(7+1)"))
# Out:
# 1+7*2
# Prefix :  +*271
# (1+7)*2
# Prefix :  *2+71

# %%
#infix to postfix


def convertPostfix(strOp) :
    stOperator = stack()
    kurung     = ("(",")")
    operator   = {"+":0,"-":0,"*":1,"/":1}
    strRes     = ""
    
    for sto in strOp :
        if sto not in operator.keys() and sto not in kurung :
            strRes+=sto
        
        elif sto == kurung[0] :
            push(stOperator,sto)
            
        elif sto == kurung[1] :
            while peek(stOperator) != kurung[0] :
                strRes+=pop(stOperator)
            pop(stOperator)
            
            
        elif sto in operator.keys() :
            while not(isEmpty(stOperator)) and peek(stOperator) != kurung[0] and operator[peek(stOperator)] >= operator[sto] :   
                strRes+=pop(stOperator)
            push(stOperator,sto)
        
            
    while not(isEmpty(stOperator)) :
        strRes+=pop(stOperator)
            
            
    return strRes


print("Postfix : ",convertPostfix("2*7+1"))
print("Postfix : ",convertPostfix("2*(7+1)"))
# Out:
# Postfix :  27*1+
# Postfix :  271+*

# %%
#postfix to infix

def postinf(postfix) :
    stOpr    = stack()
    operator = ("+","-","*","/")
    
    for pf in postfix :
        if pf not in operator :
            push(stOpr,pf)
        else :
            if not(isEmpty(stOpr)) :
                opr1   = pop(stOpr)
                opr2   = pop(stOpr)
                strOpr = "(" + opr2 + pf + opr1 + ")"
                push(stOpr,strOpr)
    
    return pop(stOpr)

print("Infix = ",postinf("AB*C/DE+-"))
# Out:
# Infix =  (((A*B)/C)-(D+E))

# %%
#prefix to infix

def reverseWrd(wrd) :
    wrl = stack()
    wrn = ""
    for w in wrd :
        push(wrl,w)

    for i in range(len(wrl)) :
        wr = pop(wrl)
        if wr == ")" :
            wrn+="("
        elif wr == "(" :
            wrn+=")"
        else :
            wrn+=wr

    return wrn

def preinf(prefix) :
    prefix = reverseWrd(prefix)
    stOpr    = stack()
    operator = ("+","-","*","/")
    
    for pf in prefix :
        if pf not in operator :
            push(stOpr,pf)
        else :
            if not(isEmpty(stOpr)) :
                opr1   = pop(stOpr)
                opr2   = pop(stOpr)
                strOpr = "(" + opr1 + pf + opr2 + ")"
                push(stOpr,strOpr)
    
    return pop(stOpr)


print("Infix = ",preinf("*2+71"))
# Out:
# Infix =  (2*(7+1))

# %%
#prefix to postfix

def reverseWrd(wrd) :
    wrl = stack()
    wrn = ""
    for w in wrd :
        push(wrl,w)

    for i in range(len(wrl)) :
        wr = pop(wrl)
        if wr == ")" :
            wrn+="("
        elif wr == "(" :
            wrn+=")"
        else :
            wrn+=wr

    return wrn

def preinf(prefix) :
    prefix = reverseWrd(prefix)
    stOpr    = stack()
    operator = ("+","-","*","/")
    
    for pf in prefix :
        if pf not in operator :
            push(stOpr,pf)
        else :
            if not(isEmpty(stOpr)) :
                opr1   = pop(stOpr)
                opr2   = pop(stOpr)
                strOpr = "(" + opr1 + pf + opr2 + ")"
                push(stOpr,strOpr)
    
    return pop(stOpr)

def convertPostfix(strOp) :
    stOperator = stack()
    kurung     = ("(",")")
    operator   = {"+":0,"-":0,"*":1,"/":1}
    strRes     = ""
    
    for sto in strOp :
        if sto not in operator.keys() and sto not in kurung :
            strRes+=sto
        
        elif sto == kurung[0] :
            push(stOperator,sto)
            
        elif sto == kurung[1] :
            while peek(stOperator) != kurung[0] :
                strRes+=pop(stOperator)
            pop(stOperator)
            
            
        elif sto in operator.keys() :
            while not(isEmpty(stOperator)) and peek(stOperator) != kurung[0] and operator[peek(stOperator)] >= operator[sto] :   
                strRes+=st.pop(stOperator)
            push(stOperator,sto)
        
            
    while not(isEmpty(stOperator)) :
        strRes+=pop(stOperator)
            
            
    return strRes

infix   = preinf("/*+AB-CDF")
postfix = convertPostfix(infix)

print("Postfix : ",postfix)
# Out:
# Postfix :  AB+CD-*F/

# %%
#task scheduling

dataProses = {}
for i in range(3) :
    nama = input("=> Masukkan nama : ")
    dataProses[nama] = int(input("=> Masukkan Waktu : "))
    
def taskScheduling(dictTask,limit) :
    print(dictTask)
    queTask   = createQueue()
    queTime   = createQueue()
    totalTime = 0
    for dt in dictTask.keys() :
        enqueue(queTask,dt)
        
    for dtm in dictTask.values() :
        enqueue(queTime,dtm)
   
    while size(queTask) > 0 :
        print(queTask)
        limitTemp = limit
        task      = dequeue(queTask)
        time      = dequeue(queTime)
        
        while limitTemp > 0 :
            limitTemp-=1
            if time > 0 :
                time-=1
                totalTime+=1
        if time > 0 :    
            que.enqueue(queTime,time)
            que.enqueue(queTask,task)
    
    return totalTime
        
print(taskScheduling(dataProses,3))
# Out:
# => Masukkan nama : agus
# => Masukkan Waktu : 3
# => Masukkan nama : vian
# => Masukkan Waktu : 2
# => Masukkan nama : alif
# => Masukkan Waktu : 1
# {'agus': 3, 'vian': 2, 'alif': 1}
# ['agus', 'vian', 'alif']
# ['vian', 'alif']
# ['alif']
# 6

# %%
#median
def median(angka) :
    deq   = createDeque()
    total = 0
    
    bubbleSort(angka)
    
    for akg in angka :
        addRear(deq,akg)
    
    if size(deq) % 2 != 0 :
    
        for dq in deq :
            removeRear(deq)
            removeFront(deq)
            if size(deq) == 1 :
                for de in deq :
                    total = de
            
                   
    else :
         for dq in deq :
            removeRear(deq)
            removeFront(deq)
            print(deq)
            if size(deq) == 2 :
                for de in deq :
                    total+=de
                    
                total = total/2
          

    return total

print(median([5,3,1,4,8,8,9]))
# Out:
# Data Awal =  [5, 3, 1, 4, 8, 8, 9]
#
# Iterasi utama ke- 1  =  [5, 3, 1, 4, 8, 8, 9]
# #1 : data[6,5] = 9 dan 8 -> [5, 3, 1, 4, 8, 9, 8]
# #2 : data[5,4] = 9 dan 8 -> [5, 3, 1, 4, 9, 8, 8]
# #3 : data[4,3] = 9 dan 4 -> [5, 3, 1, 9, 4, 8, 8]
# #4 : data[3,2] = 9 dan 1 -> [5, 3, 9, 1, 4, 8, 8]
# #5 : data[2,1] = 9 dan 3 -> [5, 9, 3, 1, 4, 8, 8]
# #6 : data[1,0] = 9 dan 5 -> [9, 5, 3, 1, 4, 8, 8]
#
# Iterasi utama ke- 2  =  [9, 5, 3, 1, 4, 8, 8]
# #1 : data[6,5] = 8 dan 8 -> [9, 5, 3, 1, 4, 8, 8]
# #2 : data[5,4] = 8 dan 4 -> [9, 5, 3, 1, 8, 4, 8]
# #3 : data[4,3] = 8 dan 1 -> [9, 5, 3, 8, 1, 4, 8]
# #4 : data[3,2] = 8 dan 3 -> [9, 5, 8, 3, 1, 4, 8]
# #5 : data[2,1] = 8 dan 5 -> [9, 8, 5, 3, 1, 4, 8]
#
# Iterasi utama ke- 3  =  [9, 8, 5, 3, 1, 4, 8]
# #1 : data[6,5] = 8 dan 4 -> [9, 8, 5, 3, 1, 8, 4]
# #2 : data[5,4] = 8 dan 1 -> [9, 8, 5, 3, 8, 1, 4]
# #3 : data[4,3] = 8 dan 3 -> [9, 8, 5, 8, 3, 1, 4]
# #4 : data[3,2] = 8 dan 5 -> [9, 8, 8, 5, 3, 1, 4]
#
# ...
